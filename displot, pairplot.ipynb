# %%
import pandas as pd
import matplotlib as ptl
import seaborn as sns

# %%
df = pd.read_csv('D:\statistics\iris.csv')
df
# Out:
#      Unnamed: 0  sepal length  sepal width  petal length  petal width  species
# 0             0           5.1          3.5           1.4          0.2        0
# 1             1           4.9          3.0           1.4          0.2        0
# 2             2           4.7          3.2           1.3          0.2        0
# 3             3           4.6          3.1           1.5          0.2        0
# 4             4           5.0          3.6           1.4          0.2        0
# ..          ...           ...          ...           ...          ...      ...
# 145         145           6.7          3.0           5.2          2.3        2
# 146         146           6.3          2.5           5.0          1.9        2
# 147         147           6.5          3.0           5.2          2.0        2
# 148         148           6.2          3.4           5.4          2.3        2
# 149         149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 6 columns]

# %%
for i in df:
    print(i)
# Out:
# Unnamed: 0
# sepal length
# sepal width
# petal length
# petal width
# species

# %%
df['petal width'].hist()

# %%
df['petal length'].hist()

# %%
df['sepal width'].hist()

# %%
df['sepal length'].hist()

# %%
sns.distplot(df['petal width'], color = "blue")
sns.distplot(df['petal length'], color ="green")
sns.distplot(df['sepal width'], color = "yellow")
sns.distplot(df['sepal length'], color = "orange")

# %%
x = df['sepal length']
type(x)
sns.distplot(x, color = 'green')

# %%
x = df['sepal width']
type(x)
sns.distplot(x, color = 'yellow')

# %%
x = df['petal length']
type(x)
sns.distplot(x, color = 'black')

# %%
x = df['petal width']
type(x)
sns.distplot(x, color = 'red')

# %%
sns.kdeplot(data = df['petal length'])
sns.kdeplot(data = df['petal width'])
sns.kdeplot(data = df['sepal length'])
sns.kdeplot(data = df['sepal length'])

# %%
sns.kdeplot(data = df['sepal length'])
sns.kdeplot(data = df['sepal length'])

# %%
sns.violinplot(y = df["petal length"])

# %%
sns.violinplot(y = "petal length", data = df)

# %%
sns.pairplot(data = df, x_vars = 'petal length', y_vars = 'petal width', kind = 'reg', height = 5 )

# %%
sns.pairplot(data = df, x_vars = 'petal length', y_vars = 'sepal width', kind = 'reg', height = 5 )

# %%
sns.pairplot(data = df, x_vars = 'sepal length', y_vars = 'sepal width', kind = 'reg', height = 5 )

# %%
sns.pairplot(df)

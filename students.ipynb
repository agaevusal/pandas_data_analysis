# %%
import pandas as pd
import numpy as np

# %%
#import matplotlib.pyplot as plt
#import seaborn as sns

# %%
students = pd.read_csv('D:\statistics\StudentsPerformance.csv')

# %%
students.loc[:]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
students.iloc[0:5, 0:3]
# Out:
#    gender race/ethnicity parental level of education
# 0  female        group B           bachelor's degree
# 1  female        group C                some college
# 2  female        group B             master's degree
# 3    male        group A          associate's degree
# 4    male        group C                some college

# %%
students.iloc[[0,3,10],  [-1,-2,-3]]
# Out:
#     writing score  reading score  math score
# 0              74             72          72
# 3              44             57          47
# 10             52             54          58

# %%
students_with_names = students.iloc[[0,3,4,7,8]]

# %%
students_with_names
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 3                    none          47             57             44
# 4                    none          76             78             75
# 7                    none          40             43             39
# 8               completed          64             64             67

# %%
students_with_names.index = ['Jafarov','Rzaev','Isaev','Mahmudov','Aliev']

# %%
students_with_names
# Out:
#           gender race/ethnicity parental level of education         lunch  \
# Jafarov   female        group B           bachelor's degree      standard
# Rzaev       male        group A          associate's degree  free/reduced
# Isaev       male        group C                some college      standard
# Mahmudov    male        group B                some college  free/reduced
# Aliev       male        group D                 high school  free/reduced
#
#          test preparation course  math score  reading score  writing score
# Jafarov                     none          72             72             74
# Rzaev                       none          47             57             44
# Isaev                       none          76             78             75
# Mahmudov                    none          40             43             39
# Aliev                  completed          64             64             67

# %%
students_with_names.loc[['Aliev','Rzaev']]
# Out:
#       gender race/ethnicity parental level of education         lunch  \
# Aliev   male        group D                 high school  free/reduced
# Rzaev   male        group A          associate's degree  free/reduced
#
#       test preparation course  math score  reading score  writing score
# Aliev               completed          64             64             67
# Rzaev                    none          47             57             44

# %%
students_with_names.loc[['Aliev','Rzaev'], ['gender','math score']]
# Out:
#       gender  math score
# Aliev   male          64
# Rzaev   male          47

# %%
type(students_with_names.loc[['Aliev','Rzaev'], ['gender','math score']])
# Out:
# pandas.core.frame.DataFrame

# %%
students_with_names.iloc[:,0]
# Out:
# Jafarov     female
# Rzaev         male
# Isaev         male
# Mahmudov      male
# Aliev         male
# Name: gender, dtype: object

# %%
type(students_with_names.iloc[:,0])
# Out:
# pandas.core.series.Series

# %%
pd.Series([1,2,3])
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
pd.Series([1,2,3], index = ['a','b','c'])
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
my_series_1 = pd.Series([1,2,3], index = ['a','b','c']) 
my_series_2 = pd.Series([4,5,6], index = ['a','b','c'])

# %%
pd.DataFrame({'name_1':my_series_1, 'name_2':my_series_2})
# Out:
#    name_1  name_2
# a       1       4
# b       2       5
# c       3       6

# %%
students.loc[students.gender == "female", ['gender','writing score', 'reading score']]
# Out:
#      gender  writing score  reading score
# 0    female             74             72
# 1    female             88             90
# 2    female             93             95
# 5    female             78             83
# 6    female             92             95
# ..      ...            ...            ...
# 993  female             74             72
# 995  female             95             99
# 997  female             65             71
# 998  female             77             78
# 999  female             86             86
#
# [518 rows x 3 columns]

# %%
mean_writing_score = students['writing score'].mean()

# %%
mean_writing_score
# Out:
# 68.054

# %%
students.gender == 'female'
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 995     True
# 996    False
# 997     True
# 998     True
# 999     True
# Name: gender, Length: 1000, dtype: bool

# %%
students.loc[students.gender == 'female']
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
students.loc[(students['writing score'] %2 == 0)  & (students.gender == 'female') ]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 9    female        group B                 high school  free/reduced
# ..      ...            ...                         ...           ...
# 984  female        group C            some high school      standard
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
query = (students['reading score'] % 5 == 0) & (students.gender == 'male')

# %%
students.loc[query]
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 28    male        group C                 high school      standard
# 43    male        group B                some college  free/reduced
# 50    male        group E                some college      standard
# 57    male        group D          associate's degree      standard
# 71    male        group D                some college      standard
# ..     ...            ...                         ...           ...
# 948   male        group B            some high school  free/reduced
# 977   male        group C          associate's degree      standard
# 982   male        group B            some high school      standard
# 987   male        group E            some high school      standard
# 996   male        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 28                     none          70             70             65
# ...

# %%
k = 0
for i in students.lunch:
    #print(i)
    if i == 'free/reduced':
        k += 1
k
# Out:
# 355

# %%
students.shape
# Out:
# (1000, 8)

# %%
k / 1000
# Out:
# 0.355

# %%
(students.lunch == 'free/reduced').mean()
# Out:
# 0.355

# %%
students.lunch
# Out:
# 0          standard
# 1          standard
# 2          standard
# 3      free/reduced
# 4          standard
#            ...
# 995        standard
# 996    free/reduced
# 997    free/reduced
# 998        standard
# 999    free/reduced
# Name: lunch, Length: 1000, dtype: object

# %%
lunch_1 = students.loc[students.lunch == 'free/reduced', ['math score','writing score', 'reading score']]

# %%
lunch_1
# Out:
#      math score  writing score  reading score
# 3            47             44             57
# 7            40             39             43
# 8            64             67             64
# 9            38             50             60
# 17           18             28             32
# ..          ...            ...            ...
# 992          55             76             76
# 993          62             74             72
# 996          62             55             55
# 997          59             65             71
# 999          77             86             86
#
# [355 rows x 3 columns]

# %%
lunch_1.mean()
# Out:
# math score       58.921127
# writing score    63.022535
# reading score    64.653521
# dtype: float64

# %%
lunch_1.var()
# Out:
# math score       229.824270
# writing score    238.202881
# reading score    221.871139
# dtype: float64

# %%
lunch_2 =  students.loc[students.lunch == 'standard', ['math score','writing score', 'reading score']]

# %%
lunch_2
# Out:
#      math score  writing score  reading score
# 0            72             74             72
# 1            69             88             90
# 2            90             93             95
# 4            76             75             78
# 5            71             78             83
# ..          ...            ...            ...
# 987          81             76             75
# 991          65             78             82
# 994          63             62             63
# 995          88             95             99
# 998          68             77             78
#
# [645 rows x 3 columns]

# %%
lunch_2.mean()
# Out:
# math score       70.034109
# writing score    70.823256
# reading score    71.654264
# dtype: float64

# %%
lunch_2.var()
# Out:
# math score       186.418089
# writing score    205.620887
# reading score    191.285560
# dtype: float64

# %%
students = students.rename(columns = {'parental level of education' : 'parental_level_of_education', 
                                      'test preparation course':'test_preparation_course','math score':'math_score',
                                     'reading score':'reading_score', 'writing score':'writing_score'})

# %%
students.head()
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
students.query('math_score > 99')
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 451  female        group E                some college      standard
# 458  female        group E           bachelor's degree      standard
# 623    male        group A                some college      standard
# 625    male        group D                some college      standard
# 916    male        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# 149               completed         100            100             93
# 451                    none         100             92             97
# 458                    none         100            100            100
# 623               completed         100             96             86
# ...

# %%
students.query(" gender == 'female' & math_score > 95")
# Out:
#      gender race/ethnicity parental_level_of_education     lunch  \
# 114  female        group E           bachelor's degree  standard
# 165  female        group C           bachelor's degree  standard
# 179  female        group D            some high school  standard
# 263  female        group E                 high school  standard
# 451  female        group E                some college  standard
# 458  female        group E           bachelor's degree  standard
# 712  female        group D                some college  standard
# 717  female        group C          associate's degree  standard
# 855  female        group B           bachelor's degree  standard
# 962  female        group E          associate's degree  standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# 114               completed          99            100            100
# 165               completed          96            100            100
# ...

# %%
math_score = 95

# %%
students.query(" gender == 'female' & math_score > @math_score")
# Out:
#      gender race/ethnicity parental_level_of_education     lunch  \
# 114  female        group E           bachelor's degree  standard
# 165  female        group C           bachelor's degree  standard
# 179  female        group D            some high school  standard
# 263  female        group E                 high school  standard
# 451  female        group E                some college  standard
# 458  female        group E           bachelor's degree  standard
# 712  female        group D                some college  standard
# 717  female        group C          associate's degree  standard
# 855  female        group B           bachelor's degree  standard
# 962  female        group E          associate's degree  standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# 114               completed          99            100            100
# 165               completed          96            100            100
# ...

# %%
list(students)
# Out:
# ['gender',
#  'race/ethnicity',
#  'parental_level_of_education',
#  'lunch',
#  'test_preparation_course',
#  'math_score',
#  'reading_score',
#  'writing_score']

# %%
[i for i in list(students) if 'score' in i ]
# Out:
# ['math_score', 'reading_score', 'writing_score']

# %%
students[['math_score', 'reading_score', 'writing_score']].head(3)
# Out:
#    math_score  reading_score  writing_score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93

# %%
students[['math_score', 'reading_score', 'writing_score']].head(3)
# Out:
#    math_score  reading_score  writing_score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93

# %%
score_columns = [i for i in list(students) if 'score' in i ]

# %%
students[score_columns]
# Out:
#      math_score  reading_score  writing_score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# ..          ...            ...            ...
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86
#
# [1000 rows x 3 columns]

# %% [markdown]
# METHOD FILTER

# %%
 students.filter(like = 'score')
# Out:
#      math_score  reading_score  writing_score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# ..          ...            ...            ...
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86
#
# [1000 rows x 3 columns]

# %%
students_with_names.filter(like = 'w')
# Out:
#           writing score
# Jafarov              74
# Rzaev                44
# Isaev                75
# Mahmudov             39
# Aliev                67

# %%
students_with_names.filter(like = 'J', axis = 0) # отбор имени в строке с J
# Out:
#          gender race/ethnicity parental level of education     lunch  \
# Jafarov  female        group B           bachelor's degree  standard
#
#         test preparation course  math score  reading score  writing score
# Jafarov                    none          72             72             74

# %% [markdown]
# Группировка и агрегация

# %%
students.groupby('gender').mean()
# Out:
#         math_score  reading_score  writing_score
# gender
# female   63.633205      72.608108      72.467181
# male     68.728216      65.473029      63.311203

# %%
students.groupby('gender').aggregate({'math_score': 'mean', 'reading_score':'mean'})
# Out:
#         math_score  reading_score
# gender
# female   63.633205      72.608108
# male     68.728216      65.473029

# %%
students.groupby('gender', as_index=False).aggregate({'math_score': 'mean', 'reading_score':'mean'})
# Out:
#    gender  math_score  reading_score
# 0  female   63.633205      72.608108
# 1    male   68.728216      65.473029

# %%
students.groupby('gender', as_index=False).aggregate({'math_score': 'mean', 'reading_score':'mean'})
# Out:
#    gender  math_score  reading_score
# 0  female   63.633205      72.608108
# 1    male   68.728216      65.473029

# %%
mean_score = students.groupby(['gender','race/ethnicity' ]).aggregate({'math_score': 'mean', 'reading_score':'mean'})

# %%
mean_score
# Out:
#                        math_score  reading_score
# gender race/ethnicity
# female group A          58.527778      69.000000
#        group B          61.403846      71.076923
#        group C          62.033333      71.944444
#        group D          65.248062      74.046512
#        group E          70.811594      75.840580
# male   group A          63.735849      61.735849
#        group B          65.930233      62.848837
#        group C          67.611511      65.424460
#        group D          69.413534      66.135338
#        group E          76.746479      70.295775

# %%
mean_score.loc[[('female','group A'), ('female','group B')]]
# Out:
#                        math_score  reading_score
# gender race/ethnicity
# female group A          58.527778      69.000000
#        group B          61.403846      71.076923

# %%
mean_scores = students.groupby(['gender','race/ethnicity' ], as_index=False).aggregate({'math_score': 'mean', 'reading_score':'mean'})

# %%
mean_scores
# Out:
#    gender race/ethnicity  math_score  reading_score
# 0  female        group A   58.527778      69.000000
# 1  female        group B   61.403846      71.076923
# 2  female        group C   62.033333      71.944444
# 3  female        group D   65.248062      74.046512
# 4  female        group E   70.811594      75.840580
# 5    male        group A   63.735849      61.735849
# 6    male        group B   65.930233      62.848837
# 7    male        group C   67.611511      65.424460
# 8    male        group D   69.413534      66.135338
# 9    male        group E   76.746479      70.295775

# %%
students.math_score.unique()
# Out:
# array([ 72,  69,  90,  47,  76,  71,  88,  40,  64,  38,  58,  65,  78,
#         50,  18,  46,  54,  66,  44,  74,  73,  67,  70,  62,  63,  56,
#         97,  81,  75,  57,  55,  53,  59,  82,  77,  33,  52,   0,  79,
#         39,  45,  60,  61,  41,  49,  30,  80,  42,  27,  43,  68,  85,
#         98,  87,  51,  99,  84,  91,  83,  89,  22, 100,  96,  94,  48,
#         35,  34,  86,  92,  37,  28,  24,  26,  95,  36,  29,  32,  93,
#         19,  23,   8], dtype=int64)

# %%
students.groupby(['gender','race/ethnicity']).math_score.nunique()
# Out:
# gender  race/ethnicity
# female  group A           29
#         group B           51
#         group C           59
#         group D           53
#         group E           44
# male    group A           38
#         group B           43
#         group C           56
#         group D           49
#         group E           38
# Name: math_score, dtype: int64

# %%
students.sort_values(['gender','math_score'], ascending=False)\
.groupby('gender').head()
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 623    male        group A                some college      standard
# 625    male        group D                some college      standard
# 916    male        group E           bachelor's degree      standard
# 306    male        group E                some college      standard
# 451  female        group E                some college      standard
# 458  female        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 114  female        group E           bachelor's degree      standard
# 263  female        group E                 high school      standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# 149               completed         100            100             93
# ...

# %%
students ['total_score'] = students.math_score + students.writing_score + students.reading_score

# %%
students.head()
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score
# 0          218
# 1          247
# 2          278
# 3          148
# 4          229

# %%
students = students.assign(total_score = np.sqrt(students.total_score))

# %%
students
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# ...

# %%
students.total_score.head()
# Out:
# 0    14.764823
# 1    15.716234
# 2    16.673332
# 3    12.165525
# 4    15.132746
# Name: total_score, dtype: float64

# %%
students.drop(['total_score', 'lunch'], axis = 1).head()
# Out:
#    gender race/ethnicity parental_level_of_education test_preparation_course  \
# 0  female        group B           bachelor's degree                    none
# 1  female        group C                some college               completed
# 2  female        group B             master's degree                    none
# 3    male        group A          associate's degree                    none
# 4    male        group C                some college                    none
#
#    math_score  reading_score  writing_score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %%
students.math_score.hist()

# %%
students.plot.scatter(x = 'math_score', y = 'reading_score')
